# %%
# !pip install telethon pandas python-dotenv pillow asyncio nest_asyncio
# Out:
# Requirement already satisfied: telethon in /usr/local/lib/python3.11/dist-packages (1.40.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (1.1.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.2.1)
# Requirement already satisfied: asyncio in /usr/local/lib/python3.11/dist-packages (3.4.3)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (1.6.0)
# Requirement already satisfied: pyaes in /usr/local/lib/python3.11/dist-packages (from telethon) (1.6.1)
# Requirement already satisfied: rsa in /usr/local/lib/python3.11/dist-packages (from telethon) (4.9.1)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from rsa->telethon) (0.6.1)

# %%
# Import all necessary libraries
import os
import pandas as pd
import asyncio
import nest_asyncio
from telethon import TelegramClient
from telethon.errors import SessionPasswordNeededError
from datetime import datetime, timezone
import re
import json
from pathlib import Path
import time

# Allow nested async loops (needed for Jupyter notebooks)
nest_asyncio.apply()

# %%
# Create a .env file in your project directory with these values:
"""
API_ID= 22693668
API_HASH=11fe37717321eac9c54c5c2a1a3e220a
PHONE_NUMBER=+251936728385
"""

# Load environment variables
from dotenv import load_dotenv
load_dotenv()

# Get API credentials from environment variables
API_ID = os.getenv('API_ID')
API_HASH = os.getenv('API_HASH')
PHONE_NUMBER = os.getenv('PHONE_NUMBER')

# If you don't want to use .env file, you can set them directly here:
# WARNING: Don't share these credentials publicly!
if not API_ID:
    API_ID = '22693668'  # Replace with your actual API ID
    API_HASH = '11fe37717321eac9c54c5c2a1a3e220a'  # Replace with your actual API hash
    PHONE_NUMBER = '+251936728385'  # Replace with your phone number

print("✅ Configuration loaded successfully!")
# Out:
# ✅ Configuration loaded successfully!

# %%
# List of Ethiopian e-commerce Telegram channels to scrape
TELEGRAM_CHANNELS = [
    '@helloomarketethiopia',
    '@modernshoppingcenter',
    '@qnashcom',
    '@classybrands',
    '@marakibrand',
    '@aradabrand2'
]

# Create directories for storing data
DATA_DIR = Path('data')
IMAGES_DIR = DATA_DIR / 'images'
CSV_OUTPUT = DATA_DIR / 'telegram_messages.csv'

# Create directories if they don't exist
DATA_DIR.mkdir(exist_ok=True)
IMAGES_DIR.mkdir(exist_ok=True)

print(f"📁 Data will be stored in: {DATA_DIR}")
print(f"🖼️ Images will be stored in: {IMAGES_DIR}")
# Out:
# 📁 Data will be stored in: data
# 🖼️ Images will be stored in: data/images

# %%
def clean_amharic_text(text):
    """
    Clean and normalize Amharic text
    This function removes unnecessary characters and normalizes the text
    """
    if not text:
        return ""

    # Remove excessive emojis and special characters
    # Keep Amharic characters, numbers, and basic punctuation
    cleaned_text = re.sub(r'[^\u1200-\u137F\u0000-\u007F\s]', ' ', text)

    # Remove multiple spaces and normalize whitespace
    cleaned_text = ' '.join(cleaned_text.split())

    # Remove excessive dots and special characters
    cleaned_text = re.sub(r'\.{3,}', '...', cleaned_text)
    cleaned_text = re.sub(r'💥{2,}', '💥', cleaned_text)

    return cleaned_text.strip()

def extract_metadata(message):
    """
    Extract useful metadata from Telegram message
    Returns a dictionary with structured information
    """
    return {
        'message_id': message.id,
        'timestamp': message.date.isoformat() if message.date else None,
        'views': getattr(message, 'views', 0),
        'sender_id': message.from_id.user_id if message.from_id else None,
        'is_forwarded': message.fwd_from is not None,
        'has_media': message.media is not None
    }

def format_timestamp(dt):
    """
    Format datetime object to match the required output format
    """
    if dt:
        return dt.strftime('%Y-%m-%d %H:%M:%S+00:00')
    return None

# %%
class EthioMartTelegramScraper:
    """
    Main class for scraping Telegram channels
    This handles all the telegram API interactions
    """

    def __init__(self, api_id, api_hash, phone_number):
        self.api_id = api_id
        self.api_hash = api_hash
        self.phone_number = phone_number
        self.client = None
        self.scraped_data = []

    async def initialize_client(self):
        """
        Initialize and authenticate the Telegram client
        """
        print("🔄 Initializing Telegram client...")

        # Create client with session file
        self.client = TelegramClient('ethiomart_session', self.api_id, self.api_hash)

        # Start the client
        await self.client.start(phone=self.phone_number)

        print("✅ Telegram client initialized successfully!")

        # Check if we're authorized
        if await self.client.is_user_authorized():
            print("✅ User is authorized!")
        else:
            print("❌ User is not authorized. Please check your credentials.")

    async def scrape_channel(self, channel_username, limit=100):
        """
        Scrape messages from a specific channel

        Args:
            channel_username: The channel username (e.g., '@channelname')
            limit: Maximum number of messages to fetch
        """
        print(f"🔄 Scraping channel: {channel_username}")

        try:
            # Get the channel entity
            channel = await self.client.get_entity(channel_username)
            print(f"📢 Found channel: {channel.title}")

            # Counter for messages processed
            message_count = 0

            # Iterate through messages
            async for message in self.client.iter_messages(channel, limit=limit):
                try:
                    # Extract basic message data
                    message_data = {
                        'message_id': message.id,
                        'channel': channel_username,
                        'text': clean_amharic_text(message.text) if message.text else '',
                        'timestamp': format_timestamp(message.date),
                        'views': getattr(message, 'views', 0) or 0,
                        'sender': getattr(message.from_id, 'user_id', channel.id) if message.from_id else channel.id,
                        'image_path': ''
                    }

                    # Handle media (images)
                    if message.media and hasattr(message.media, 'photo'):
                        image_filename = f"telegram_image_{channel_username.replace('@', '')}_{message.id}.jpg"
                        image_path = IMAGES_DIR / image_filename

                        try:
                            # Download the image
                            await self.client.download_media(message.media, file=str(image_path))
                            message_data['image_path'] = f"../data/images/{image_filename}"
                            print(f"📷 Downloaded image: {image_filename}")
                        except Exception as e:
                            print(f"⚠️ Failed to download image: {e}")

                    # Add to our dataset
                    self.scraped_data.append(message_data)
                    message_count += 1

                    # Show progress every 10 messages
                    if message_count % 10 == 0:
                        print(f"📊 Processed {message_count} messages from {channel_username}")

                except Exception as e:
                    print(f"⚠️ Error processing message {message.id}: {e}")
                    continue

            print(f"✅ Completed scraping {channel_username}: {message_count} messages")

        except Exception as e:
            print(f"❌ Error scraping channel {channel_username}: {e}")

    async def scrape_all_channels(self, message_limit=100):
        """
        Scrape all configured channels

        Args:
            message_limit: Maximum messages per channel
        """
        print(f"🚀 Starting to scrape {len(TELEGRAM_CHANNELS)} channels...")

        for channel in TELEGRAM_CHANNELS:
            await self.scrape_channel(channel, limit=message_limit)

            # Add a small delay between channels to be respectful
            print("⏳ Waiting 2 seconds before next channel...")
            await asyncio.sleep(2)

        print("🎉 All channels scraped successfully!")

    def save_to_csv(self, filename=None):
        """
        Save scraped data to CSV file
        """
        if not filename:
            filename = CSV_OUTPUT

        if not self.scraped_data:
            print("⚠️ No data to save!")
            return

        # Create DataFrame
        df = pd.DataFrame(self.scraped_data)

        # Ensure proper column order to match the required output
        columns_order = ['message_id', 'channel', 'text', 'timestamp', 'views', 'sender', 'image_path']
        df = df[columns_order]

        # Save to CSV
        df.to_csv(filename, index=False, encoding='utf-8')
        print(f"💾 Data saved to: {filename}")
        print(f"📊 Total messages saved: {len(df)}")

        # Show sample of the data
        print("\n📋 Sample data:")
        print(df.head())

        return df

    async def close(self):
        """
        Close the Telegram client connection
        """
        if self.client:
            await self.client.disconnect()
            print("🔌 Telegram client disconnected")

# %%
async def main():
    """
    Main function to run the scraping process
    """
    print("🎯 EthioMart Telegram Data Ingestion System")
    print("=" * 50)

    # Initialize scraper
    scraper = EthioMartTelegramScraper(API_ID, API_HASH, PHONE_NUMBER)

    try:
        # Initialize client
        await scraper.initialize_client()

        # Scrape all channels (adjust limit as needed)
        await scraper.scrape_all_channels(message_limit=5000)  # Increased to scrape around 30000 messages

        # Save data to CSV
        df = scraper.save_to_csv()

        print("\n🎉 Data ingestion completed successfully!")
        print(f"📊 Total messages collected: {len(scraper.scraped_data)}")
        print(f"📁 Data saved to: {CSV_OUTPUT}")

    except Exception as e:
        print(f"❌ Error during execution: {e}")

    finally:
        # Always close the client
        await scraper.close()

# %%
def analyze_collected_data(csv_file=CSV_OUTPUT):
    """
    Analyze the collected data and show statistics
    """
    if not os.path.exists(csv_file):
        print(f"❌ CSV file not found: {csv_file}")
        return

    # Load the data
    df = pd.read_csv(csv_file)

    print("📊 DATA ANALYSIS REPORT")
    print("=" * 30)
    print(f"Total messages: {len(df)}")
    print(f"Channels scraped: {df['channel'].nunique()}")
    print(f"Messages with images: {len(df[df['image_path'] != ''])}")
    print(f"Messages with text: {len(df[df['text'] != ''])}")

    print("\n📈 Messages per channel:")
    channel_counts = df['channel'].value_counts()
    for channel, count in channel_counts.items():
        print(f"  {channel}: {count} messages")

    print("\n📋 Sample messages:")
    print(df[['channel', 'text', 'timestamp']].head())

    return df

# %%
# Run the main scraping function
await main()
# Out:
# 🎯 EthioMart Telegram Data Ingestion System
# ==================================================
# 🔄 Initializing Telegram client...
# Signed in successfully as Ruhama; remember to not break the ToS or you will risk an account ban!
# ✅ Telegram client initialized successfully!
# ✅ User is authorized!
# 🚀 Starting to scrape 6 channels...
# 🔄 Scraping channel: @helloomarketethiopia
# 📢 Found channel: HellooMarket
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4562.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4561.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4560.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4559.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4558.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4557.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4556.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4555.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4554.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4553.jpg
# 📊 Processed 10 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4552.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4551.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4550.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4549.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4548.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4547.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4546.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4545.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4544.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4543.jpg
# 📊 Processed 20 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4542.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4541.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4540.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4539.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4538.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4537.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4536.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4535.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4534.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4533.jpg
# 📊 Processed 30 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4531.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4530.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4528.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4527.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4526.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4525.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4524.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4523.jpg
# 📊 Processed 40 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4521.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4520.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4519.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4518.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4517.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4516.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4515.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4514.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4513.jpg
# 📊 Processed 50 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4511.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4508.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4507.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4506.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4505.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4504.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4503.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4502.jpg
# 📊 Processed 60 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4500.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4499.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4498.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4497.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4496.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4495.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4493.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4492.jpg
# 📊 Processed 70 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4491.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4490.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4489.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4488.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4487.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4485.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4484.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4483.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4482.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4481.jpg
# 📊 Processed 80 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4480.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4479.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4478.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4477.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4476.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4475.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4474.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4473.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4472.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4471.jpg
# 📊 Processed 90 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4470.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4469.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4468.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4467.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4466.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4465.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4463.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4462.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4461.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4459.jpg
# 📊 Processed 100 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4458.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4457.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4456.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4455.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4454.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4453.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4452.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4451.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4450.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4449.jpg
# 📊 Processed 110 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4448.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4446.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4445.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4444.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4443.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4441.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4440.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4439.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4438.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4437.jpg
# 📊 Processed 120 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4436.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4435.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4434.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4433.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4432.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4431.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4430.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4429.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4428.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4427.jpg
# 📊 Processed 130 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4426.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4425.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4424.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4423.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4420.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4418.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4417.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4415.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4414.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4413.jpg
# 📊 Processed 140 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4412.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4411.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4410.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4408.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4405.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4404.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4403.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4402.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4400.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4399.jpg
# 📊 Processed 150 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4397.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4396.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4395.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4394.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4393.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4392.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4391.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4390.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4389.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4388.jpg
# 📊 Processed 160 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4387.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4385.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4384.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4383.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4382.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4381.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4380.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4379.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4378.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4377.jpg
# 📊 Processed 170 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4376.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4375.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4374.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4373.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4372.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4371.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4370.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4369.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4368.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4367.jpg
# 📊 Processed 180 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4366.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4365.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4364.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4363.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4362.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4361.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4360.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4359.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4358.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4357.jpg
# 📊 Processed 190 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4356.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4355.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4354.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4353.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4352.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4351.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4350.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4349.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4348.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4347.jpg
# 📊 Processed 200 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4346.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4345.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4344.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4343.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4342.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4341.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4340.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4339.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4338.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4337.jpg
# 📊 Processed 210 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4336.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4335.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4334.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4333.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4332.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4331.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4330.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4329.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4328.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4327.jpg
# 📊 Processed 220 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4326.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4325.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4324.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4323.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4322.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4321.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4320.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4319.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4318.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4317.jpg
# 📊 Processed 230 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4316.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4315.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4314.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4313.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4312.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4311.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4310.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4309.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4308.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4307.jpg
# 📊 Processed 240 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4306.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4305.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4304.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4303.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4302.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4301.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4300.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4299.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4298.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4297.jpg
# 📊 Processed 250 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4296.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4295.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4294.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4293.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4292.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4291.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4290.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4289.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4288.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4287.jpg
# 📊 Processed 260 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4286.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4285.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4284.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4283.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4282.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4281.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4280.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4279.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4278.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4277.jpg
# 📊 Processed 270 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4276.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4275.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4274.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4273.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4272.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4270.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4269.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4268.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4267.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4266.jpg
# 📊 Processed 280 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4265.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4264.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4263.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4262.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4261.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4260.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4259.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4258.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4257.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4256.jpg
# 📊 Processed 290 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4255.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4254.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4253.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4252.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4251.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4250.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4249.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4248.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4247.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4246.jpg
# 📊 Processed 300 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4245.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4244.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4243.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4242.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4241.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4239.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4238.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4237.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4236.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4235.jpg
# 📊 Processed 310 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4234.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4233.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4232.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4231.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4230.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4229.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4228.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4227.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4226.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4223.jpg
# 📊 Processed 320 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4222.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4221.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4220.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4219.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4218.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4217.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4216.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4215.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4214.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4213.jpg
# 📊 Processed 330 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4210.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4209.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4208.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4207.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4206.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4205.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4204.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4203.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4202.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4201.jpg
# 📊 Processed 340 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4200.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4198.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4197.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4196.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4195.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4194.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4193.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4192.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4191.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4190.jpg
# 📊 Processed 350 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4189.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4188.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4187.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4186.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4185.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4184.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4183.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4182.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4181.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4180.jpg
# 📊 Processed 360 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4179.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4178.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4177.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4176.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4175.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4174.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4173.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4172.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4171.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4170.jpg
# 📊 Processed 370 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4169.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4168.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4167.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4166.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4165.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4164.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4163.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4162.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4160.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4159.jpg
# 📊 Processed 380 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4158.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4157.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4156.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4155.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4154.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4153.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4152.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4151.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4150.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4149.jpg
# 📊 Processed 390 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4148.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4147.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4146.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4145.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4144.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4143.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4142.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4141.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4140.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4139.jpg
# 📊 Processed 400 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4138.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4137.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4136.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4135.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4134.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4133.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4132.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4131.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4130.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4129.jpg
# 📊 Processed 410 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4128.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4127.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4126.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4125.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4124.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4123.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4122.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4121.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4120.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4119.jpg
# 📊 Processed 420 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4118.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4117.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4116.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4115.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4114.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4113.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4112.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4111.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4110.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4109.jpg
# 📊 Processed 430 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4108.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4107.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4106.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4105.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4104.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4103.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4102.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4101.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4100.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4099.jpg
# 📊 Processed 440 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4098.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4097.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4096.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4095.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4094.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4093.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4091.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4090.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4089.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4088.jpg
# 📊 Processed 450 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4087.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4086.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4085.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4084.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4083.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4080.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4079.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4078.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4076.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4075.jpg
# 📊 Processed 460 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4074.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4073.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4072.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4071.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4070.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4069.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4068.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4067.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4066.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4065.jpg
# 📊 Processed 470 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4064.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4063.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4062.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4061.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4060.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4059.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4058.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4057.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4056.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4055.jpg
# 📊 Processed 480 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4054.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4053.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4052.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4051.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4050.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4049.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4048.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4047.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4046.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4045.jpg
# 📊 Processed 490 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4044.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4043.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4042.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4041.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4040.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4039.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4038.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4037.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4036.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4035.jpg
# 📊 Processed 500 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4034.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4033.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4032.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4031.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4030.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4029.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4028.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4027.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4026.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4025.jpg
# 📊 Processed 510 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4023.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4022.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4021.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4020.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4019.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4018.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4017.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4016.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4015.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4014.jpg
# 📊 Processed 520 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4013.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4012.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4011.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4010.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4009.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4008.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4007.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4006.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4005.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4004.jpg
# 📊 Processed 530 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4003.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4002.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4001.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_4000.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3999.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3998.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3997.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3996.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3995.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3994.jpg
# 📊 Processed 540 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3993.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3992.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3991.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3990.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3989.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3988.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3987.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3986.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3985.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3984.jpg
# 📊 Processed 550 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3983.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3982.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3981.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3980.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3979.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3978.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3977.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3976.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3975.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3974.jpg
# 📊 Processed 560 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3973.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3972.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3971.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3970.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3969.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3968.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3967.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3966.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3965.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3964.jpg
# 📊 Processed 570 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3963.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3962.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3961.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3960.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3959.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3958.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3957.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3956.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3954.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3953.jpg
# 📊 Processed 580 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3952.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3951.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3950.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3949.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3948.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3947.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3946.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3944.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3943.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3942.jpg
# 📊 Processed 590 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3941.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3940.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3939.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3938.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3937.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3936.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3935.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3934.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3933.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3932.jpg
# 📊 Processed 600 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3931.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3930.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3929.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3928.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3927.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3926.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3925.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3923.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3922.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3921.jpg
# 📊 Processed 610 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3920.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3919.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3918.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3917.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3916.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3915.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3914.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3913.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3912.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3911.jpg
# 📊 Processed 620 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3910.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3909.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3908.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3907.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3906.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3905.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3904.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3903.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3902.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3901.jpg
# 📊 Processed 630 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3900.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3899.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3898.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3897.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3896.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3895.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3894.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3893.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3892.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3891.jpg
# 📊 Processed 640 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3890.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3889.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3888.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3887.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3886.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3885.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3884.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3883.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3882.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3881.jpg
# 📊 Processed 650 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3880.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3879.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3878.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3877.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3875.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3874.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3873.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3872.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3871.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3870.jpg
# 📊 Processed 660 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3869.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3868.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3867.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3866.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3865.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3864.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3863.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3862.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3861.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3860.jpg
# 📊 Processed 670 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3859.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3858.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3857.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3856.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3855.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3854.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3853.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3852.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3851.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3850.jpg
# 📊 Processed 680 messages from @helloomarketethiopia
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3849.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3848.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3847.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3846.jpg
# 📷 Downloaded image: telegram_image_helloomarketethiopia_3845.jpg
# ...
# 📷 Downloaded image: telegram_image_aradabrand2_6846.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6845.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6844.jpg
# 📊 Processed 4760 messages from @aradabrand2
# 📷 Downloaded image: telegram_image_aradabrand2_6843.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6819.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6818.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6817.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6809.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6808.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6807.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6806.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6805.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6804.jpg
# 📊 Processed 4770 messages from @aradabrand2
# 📷 Downloaded image: telegram_image_aradabrand2_6802.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6801.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6800.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6799.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6798.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6797.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6791.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6789.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6788.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6787.jpg
# 📊 Processed 4780 messages from @aradabrand2
# 📷 Downloaded image: telegram_image_aradabrand2_6782.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6781.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6779.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6764.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6763.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6762.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6761.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6760.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6759.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6758.jpg
# 📊 Processed 4790 messages from @aradabrand2
# 📷 Downloaded image: telegram_image_aradabrand2_6757.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6756.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6755.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6754.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6753.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6752.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6742.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6741.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6740.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6739.jpg
# 📊 Processed 4800 messages from @aradabrand2
# 📷 Downloaded image: telegram_image_aradabrand2_6738.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6737.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6736.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6733.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6732.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6731.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6730.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6729.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6728.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6727.jpg
# 📊 Processed 4810 messages from @aradabrand2
# 📷 Downloaded image: telegram_image_aradabrand2_6726.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6725.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6724.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6723.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6722.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6721.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6720.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6719.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6718.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6717.jpg
# 📊 Processed 4820 messages from @aradabrand2
# 📷 Downloaded image: telegram_image_aradabrand2_6716.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6715.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6714.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6713.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6710.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6709.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6708.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6707.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6706.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6678.jpg
# 📊 Processed 4830 messages from @aradabrand2
# 📷 Downloaded image: telegram_image_aradabrand2_6677.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6676.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6674.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6673.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6672.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6671.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6670.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6669.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6668.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6667.jpg
# 📊 Processed 4840 messages from @aradabrand2
# 📷 Downloaded image: telegram_image_aradabrand2_6666.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6665.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6664.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6663.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6662.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6661.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6660.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6659.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6658.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6657.jpg
# 📊 Processed 4850 messages from @aradabrand2
# 📷 Downloaded image: telegram_image_aradabrand2_6654.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6653.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6650.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6649.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6648.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6647.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6646.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6645.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6644.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6643.jpg
# 📊 Processed 4860 messages from @aradabrand2
# 📷 Downloaded image: telegram_image_aradabrand2_6642.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6617.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6616.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6615.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6614.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6613.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6612.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6611.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6610.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6609.jpg
# 📊 Processed 4870 messages from @aradabrand2
# 📷 Downloaded image: telegram_image_aradabrand2_6608.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6607.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6606.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6605.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6604.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6603.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6602.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6601.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6599.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6598.jpg
# 📊 Processed 4880 messages from @aradabrand2
# 📷 Downloaded image: telegram_image_aradabrand2_6597.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6596.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6595.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6594.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6593.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6592.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6591.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6590.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6589.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6588.jpg
# 📊 Processed 4890 messages from @aradabrand2
# 📷 Downloaded image: telegram_image_aradabrand2_6587.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6586.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6585.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6584.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6583.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6582.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6581.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6580.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6579.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6578.jpg
# 📊 Processed 4900 messages from @aradabrand2
# 📷 Downloaded image: telegram_image_aradabrand2_6576.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6575.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6574.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6573.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6571.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6570.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6569.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6568.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6567.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6566.jpg
# 📊 Processed 4910 messages from @aradabrand2
# 📷 Downloaded image: telegram_image_aradabrand2_6565.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6564.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6563.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6562.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6561.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6560.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6559.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6558.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6557.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6556.jpg
# 📊 Processed 4920 messages from @aradabrand2
# 📷 Downloaded image: telegram_image_aradabrand2_6555.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6554.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6553.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6552.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6551.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6550.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6549.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6548.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6547.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6546.jpg
# 📊 Processed 4930 messages from @aradabrand2
# 📷 Downloaded image: telegram_image_aradabrand2_6545.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6544.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6542.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6541.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6540.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6539.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6538.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6537.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6536.jpg
# 📊 Processed 4940 messages from @aradabrand2
# 📷 Downloaded image: telegram_image_aradabrand2_6534.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6533.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6532.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6531.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6530.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6529.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6527.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6525.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6524.jpg
# 📊 Processed 4950 messages from @aradabrand2
# 📷 Downloaded image: telegram_image_aradabrand2_6523.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6522.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6521.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6520.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6519.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6517.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6516.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6515.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6514.jpg
# 📊 Processed 4960 messages from @aradabrand2
# 📷 Downloaded image: telegram_image_aradabrand2_6512.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6511.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6510.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6502.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6501.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6500.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6499.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6498.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6497.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6496.jpg
# 📊 Processed 4970 messages from @aradabrand2
# 📷 Downloaded image: telegram_image_aradabrand2_6495.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6494.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6493.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6492.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6490.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6489.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6488.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6487.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6483.jpg
# 📊 Processed 4980 messages from @aradabrand2
# 📷 Downloaded image: telegram_image_aradabrand2_6482.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6481.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6480.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6479.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6477.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6476.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6474.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6459.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6458.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6457.jpg
# 📊 Processed 4990 messages from @aradabrand2
# 📷 Downloaded image: telegram_image_aradabrand2_6456.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6455.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6454.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6453.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6452.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6451.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6448.jpg
# 📷 Downloaded image: telegram_image_aradabrand2_6446.jpg
# 📊 Processed 5000 messages from @aradabrand2
# ✅ Completed scraping @aradabrand2: 5000 messages
# ⏳ Waiting 2 seconds before next channel...
# 🎉 All channels scraped successfully!
# 💾 Data saved to: data/telegram_messages.csv
# 📊 Total messages saved: 27520
#
# 📋 Sample data:
#    message_id                channel  \
# 0        4562  @helloomarketethiopia
# 1        4561  @helloomarketethiopia
# 2        4560  @helloomarketethiopia
# 3        4559  @helloomarketethiopia
# 4        4558  @helloomarketethiopia
#
#                                                 text  \
# 0  **ሁለት **ሲገዙ **5%** ቅናሽ ሙሉ በሙሉ የመኝታ ቤትዎን ውበት የሚ...
# 1  የልጆች ወብ ባማረ ዲዛይን የተሰራ ቀሚስ ለማዘዝ 0974312223 ይደውሉ...
# 2  አስደናቄ አትዮጵያዊ ምስልሎች ያላቸው የአረቄ መለኪያ ለማዘዝ 0974312...
# 3  ብዙ ተወዳጀነትን የተረፈ የቃልኪዳን ጉዞ ለሁሉም እድሜ የሚሆን የአማረኛ ...
# 4  ለቤትዎ ደምቀት የሚጨምሩ ሻማዎች በተለያየ መጠን እና ቀለም ለማዘዝ 097...
#
#                    timestamp  views      sender  \
# 0  2025-05-23 13:34:44+00:00   2334  1403573865
# 1  2025-05-16 13:18:16+00:00   3324  1403573865
# 2  2025-05-12 13:45:37+00:00   3626  1403573865
# 3  2025-05-10 09:47:16+00:00   3458  1403573865
# 4  2025-05-09 09:35:20+00:00   3040  1403573865
#
#                                           image_path
# 0  ../data/images/telegram_image_helloomarketethi...
# 1  ../data/images/telegram_image_helloomarketethi...
# 2  ../data/images/telegram_image_helloomarketethi...
# 3  ../data/images/telegram_image_helloomarketethi...
# 4  ../data/images/telegram_image_helloomarketethi...
#
# 🎉 Data ingestion completed successfully!
# 📊 Total messages collected: 27520
# 📁 Data saved to: data/telegram_messages.csv
# 🔌 Telegram client disconnected

# %%
# Analyze the collected data to confirm it works
df = analyze_collected_data()
# Out:
# 📊 DATA ANALYSIS REPORT
# ==============================
# Total messages: 27520
# Channels scraped: 6
# Messages with images: 27520
# Messages with text: 27520
#
# 📈 Messages per channel:
#   @modernshoppingcenter: 5000 messages
#   @classybrands: 5000 messages
#   @aradabrand2: 5000 messages
#   @marakibrand: 5000 messages
#   @qnashcom: 3911 messages
#   @helloomarketethiopia: 3609 messages
#
# 📋 Sample messages:
#                  channel                                               text  \
# 0  @helloomarketethiopia  **ሁለት **ሲገዙ **5%** ቅናሽ ሙሉ በሙሉ የመኝታ ቤትዎን ውበት የሚ...
# 1  @helloomarketethiopia  የልጆች ወብ ባማረ ዲዛይን የተሰራ ቀሚስ ለማዘዝ 0974312223 ይደውሉ...
# 2  @helloomarketethiopia  አስደናቄ አትዮጵያዊ ምስልሎች ያላቸው የአረቄ መለኪያ ለማዘዝ 0974312...
# 3  @helloomarketethiopia  ብዙ ተወዳጀነትን የተረፈ የቃልኪዳን ጉዞ ለሁሉም እድሜ የሚሆን የአማረኛ ...
# 4  @helloomarketethiopia  ለቤትዎ ደምቀት የሚጨምሩ ሻማዎች በተለያየ መጠን እና ቀለም ለማዘዝ 097...
#
#                    timestamp
# 0  2025-05-23 13:34:44+00:00
# 1  2025-05-16 13:18:16+00:00
# 2  2025-05-12 13:45:37+00:00
# 3  2025-05-10 09:47:16+00:00
# 4  2025-05-09 09:35:20+00:00
