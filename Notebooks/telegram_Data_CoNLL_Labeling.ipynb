# %%
import pandas as pd
import re
import os
from typing import List, Tuple

# %%
# Load the dataset
def load_telegram_data(file_path: str = 'telegram_data.csv'):
    """Load the telegram dataset"""
    try:
        df = pd.read_csv(file_path)
        print(f"Dataset loaded successfully with {len(df)} rows")
        print(f"Columns: {list(df.columns)}")
        return df
    except FileNotFoundError:
        print(f"File {file_path} not found. Please ensure the file exists in the current directory.")
        return None
    except Exception as e:
        print(f"Error loading data: {e}")
        return None

# Load data
df = load_telegram_data()
if df is not None:
    print("\nFirst few messages:")
    print(df['text'].head())
# Out:
# Dataset loaded successfully with 27520 rows
# Columns: ['message_id', 'channel', 'text', 'timestamp', 'views', 'sender', 'image_path']
#
# First few messages:
# 0    **ሁለት **ሲገዙ **5%** ቅናሽ ሙሉ በሙሉ የመኝታ ቤትዎን ውበት የሚ...
# 1    የልጆች ወብ ባማረ ዲዛይን የተሰራ ቀሚስ ለማዘዝ 0974312223 ይደውሉ...
# 2    አስደናቄ አትዮጵያዊ ምስልሎች ያላቸው የአረቄ መለኪያ ለማዘዝ 0974312...
# 3    ብዙ ተወዳጀነትን የተረፈ የቃልኪዳን ጉዞ ለሁሉም እድሜ የሚሆን የአማረኛ ...
# 4    ለቤትዎ ደምቀት የሚጨምሩ ሻማዎች በተለያየ መጠን እና ቀለም ለማዘዝ 097...
# Name: text, dtype: object

# %%
## Step 2: Text Preprocessing and Tokenization

def clean_and_tokenize(text: str) -> List[str]:
    """
    Clean and tokenize Amharic text
    """
    if pd.isna(text) or text == '':
        return []

    # Remove extra whitespaces and normalize
    text = re.sub(r'\s+', ' ', str(text).strip())

    # Split by whitespace (basic tokenization for Amharic)
    tokens = text.split()

    # Filter out empty tokens
    tokens = [token for token in tokens if token.strip()]

    return tokens

def display_sample_messages(df: pd.DataFrame, n: int = 5):
    """Display sample messages with their tokenization"""
    print("Sample messages and their tokenization:")
    print("=" * 50)

    for i in range(min(n, len(df))):
        # Corrected line: Accessing the 'text' column instead of 'Message'
        message = df.iloc[i]['text']
        if pd.notna(message):
            tokens = clean_and_tokenize(message)
            print(f"\nMessage {i+1}: {message}")
            print(f"Tokens: {tokens}")
            print(f"Token count: {len(tokens)}")

# Display sample messages
if df is not None:
    display_sample_messages(df)
# Out:
# Sample messages and their tokenization:
# ==================================================
#
# Message 1: **ሁለት **ሲገዙ **5%** ቅናሽ ሙሉ በሙሉ የመኝታ ቤትዎን ውበት የሚጨምር አነሶላ ለማዘዝ 8420 ይደውሉ ወይም https://t.me/helloo_market_bot?start=175610010 ይጠቀሙ! **መጠን: 2.40 * 1.75** **ብዛት: ሁለት አንሶላ እና ሁለት የተራስ ልብስ** #Madeinethiopia #Bedding #Ethiopian #Marketplace #BuyEthiopia
# Tokens: ['**ሁለት', '**ሲገዙ', '**5%**', 'ቅናሽ', 'ሙሉ', 'በሙሉ', 'የመኝታ', 'ቤትዎን', 'ውበት', 'የሚጨምር', 'አነሶላ', 'ለማዘዝ', '8420', 'ይደውሉ', 'ወይም', 'https://t.me/helloo_market_bot?start=175610010', 'ይጠቀሙ!', '**መጠን:', '2.40', '*', '1.75**', '**ብዛት:', 'ሁለት', 'አንሶላ', 'እና', 'ሁለት', 'የተራስ', 'ልብስ**', '#Madeinethiopia', '#Bedding', '#Ethiopian', '#Marketplace', '#BuyEthiopia']
# Token count: 33
#
# Message 2: የልጆች ወብ ባማረ ዲዛይን የተሰራ ቀሚስ ለማዘዝ 0974312223 ይደውሉ ወይም https://t.me/helloo_market_bot?start=176010001 ይጠቀሙ! መጠን: S: L እና M #Madeinethiopia #Kids #KidsFashion #Ethiopian #Marketplace #BuyEthiopia
# Tokens: ['የልጆች', 'ወብ', 'ባማረ', 'ዲዛይን', 'የተሰራ', 'ቀሚስ', 'ለማዘዝ', '0974312223', 'ይደውሉ', 'ወይም', 'https://t.me/helloo_market_bot?start=176010001', 'ይጠቀሙ!', 'መጠን:', 'S:', 'L', 'እና', 'M', '#Madeinethiopia', '#Kids', '#KidsFashion', '#Ethiopian', '#Marketplace', '#BuyEthiopia']
# Token count: 23
#
# Message 3: አስደናቄ አትዮጵያዊ ምስልሎች ያላቸው የአረቄ መለኪያ ለማዘዝ 0974312223 ይደውሉ ወይም https://t.me/helloo_market_bot?start=160010001 ይጠቀሙ! #Madeinethiopia #HomeDecor #Ethiopian #Marketplace #BuyEthiopia
# Tokens: ['አስደናቄ', 'አትዮጵያዊ', 'ምስልሎች', 'ያላቸው', 'የአረቄ', 'መለኪያ', 'ለማዘዝ', '0974312223', 'ይደውሉ', 'ወይም', 'https://t.me/helloo_market_bot?start=160010001', 'ይጠቀሙ!', '#Madeinethiopia', '#HomeDecor', '#Ethiopian', '#Marketplace', '#BuyEthiopia']
# Token count: 17
#
# Message 4: ብዙ ተወዳጀነትን የተረፈ የቃልኪዳን ጉዞ ለሁሉም እድሜ የሚሆን የአማረኛ ስዕላዊ እና መሳጭ ታሪክ በቀለም እትመት ለማዘዝ 0974312223 ይደውሉ ወይም https://t.me/helloo_market_bot?start=121910003 ይጠቀሙ! #Madeinethiopia #Books #Ethiopian #Marketplace #BuyEthiopia
# Tokens: ['ብዙ', 'ተወዳጀነትን', 'የተረፈ', 'የቃልኪዳን', 'ጉዞ', 'ለሁሉም', 'እድሜ', 'የሚሆን', 'የአማረኛ', 'ስዕላዊ', 'እና', 'መሳጭ', 'ታሪክ', 'በቀለም', 'እትመት', 'ለማዘዝ', '0974312223', 'ይደውሉ', 'ወይም', 'https://t.me/helloo_market_bot?start=121910003', 'ይጠቀሙ!', '#Madeinethiopia', '#Books', '#Ethiopian', '#Marketplace', '#BuyEthiopia']
# Token count: 26
#
# Message 5: ለቤትዎ ደምቀት የሚጨምሩ ሻማዎች በተለያየ መጠን እና ቀለም ለማዘዝ 0974312223 ይደውሉ ወይም https://t.me/helloo_market_bot?start=020010001 https://t.me/helloo_market_bot?start=020010002 https://t.me/helloo_market_bot?start=020010003 ይጠቀሙ! #Madeinethiopia #HomeDecor #Candles #Ethiopian #Marketplace #BuyEthiopia
# Tokens: ['ለቤትዎ', 'ደምቀት', 'የሚጨምሩ', 'ሻማዎች', 'በተለያየ', 'መጠን', 'እና', 'ቀለም', 'ለማዘዝ', '0974312223', 'ይደውሉ', 'ወይም', 'https://t.me/helloo_market_bot?start=020010001', 'https://t.me/helloo_market_bot?start=020010002', 'https://t.me/helloo_market_bot?start=020010003', 'ይጠቀሙ!', '#Madeinethiopia', '#HomeDecor', '#Candles', '#Ethiopian', '#Marketplace', '#BuyEthiopia']
# Token count: 22

# %%
## Step 3: Manual Labeling Interface
class AmharicNERLabeler:
    def __init__(self):
        self.entity_types = {
            'B-Product': 'Beginning of Product entity',
            'I-Product': 'Inside Product entity',
            'B-LOC': 'Beginning of Location entity',
            'I-LOC': 'Inside Location entity',
            'B-PRICE': 'Beginning of Price entity',
            'I-PRICE': 'Inside Price entity',
            'O': 'Outside any entity'
        }
        self.labeled_data = []

    def display_guidelines(self):
        """Display labeling guidelines"""
        print("LABELING GUIDELINES:")
        print("=" * 40)
        print("Entity Types:")
        for tag, description in self.entity_types.items():
            print(f"  {tag}: {description}")
        print("\nExamples:")
        print("  'Baby bottle' -> Baby(B-Product) bottle(I-Product)")
        print("  'Addis Abeba' -> Addis(B-LOC) Abeba(I-LOC)")
        print("  'ዋጋ 1000 ብር' -> ዋጋ(B-PRICE) 1000(I-PRICE) ብር(I-PRICE)")
        print("  Other words -> O")
        print("\n" + "=" * 40)

    def label_message(self, message: str, message_id: int):
        """
        Interactively label a single message
        """
        tokens = clean_and_tokenize(message)

        if not tokens:
            return None

        print(f"\nMessage {message_id}: {message}")
        print(f"Tokens to label: {tokens}")
        print("\nEnter labels for each token (or 'skip' to skip this message):")

        labeled_tokens = []

        for i, token in enumerate(tokens):
            while True:
                label = input(f"Token {i+1} '{token}': ").strip()

                if label.lower() == 'skip':
                    return None

                if label in self.entity_types:
                    labeled_tokens.append((token, label))
                    break
                else:
                    print(f"Invalid label. Choose from: {list(self.entity_types.keys())}")

        return labeled_tokens

    def save_conll_format(self, output_file: str = 'amharic_ner_conll.txt'):
        """
        Save labeled data in CoNLL format
        """
        with open(output_file, 'w', encoding='utf-8') as f:
            for message_data in self.labeled_data:
                for token, label in message_data:
                    f.write(f"{token}\t{label}\n")
                f.write("\n")  # Blank line between messages

        print(f"Data saved to {output_file} in CoNLL format")

    def display_progress(self):
        """Display labeling progress"""
        print(f"\nProgress: {len(self.labeled_data)} messages labeled")
        if len(self.labeled_data) >= 30:
            print("✅ Minimum requirement met (30 messages)")
        else:
            print(f"⏳ Need {30 - len(self.labeled_data)} more messages")

# Initialize labeler
labeler = AmharicNERLabeler()
labeler.display_guidelines()
# Out:
# LABELING GUIDELINES:
# ========================================
# Entity Types:
#   B-Product: Beginning of Product entity
#   I-Product: Inside Product entity
#   B-LOC: Beginning of Location entity
#   I-LOC: Inside Location entity
#   B-PRICE: Beginning of Price entity
#   I-PRICE: Inside Price entity
#   O: Outside any entity
#
# Examples:
#   'Baby bottle' -> Baby(B-Product) bottle(I-Product)
#   'Addis Abeba' -> Addis(B-LOC) Abeba(I-LOC)
#   'ዋጋ 1000 ብር' -> ዋጋ(B-PRICE) 1000(I-PRICE) ብር(I-PRICE)
#   Other words -> O
#
# ========================================

# %%
# Load dataset
import pandas as pd
import re

file_path = 'telegram_data.csv'
df = pd.read_csv(file_path)

# Debug: Check what columns exist
print("Available columns:", df.columns.tolist())
print("First few rows:")
print(df.head())

# Handle different possible column names
text_column = None
if 'clean_text' in df.columns:
    text_column = 'clean_text'
elif 'Message' in df.columns:
    text_column = 'Message'
elif 'text' in df.columns:
    text_column = 'text'
elif 'message' in df.columns:
    text_column = 'message'
else:
    # Try to find any column that might contain text
    for col in df.columns:
        if df[col].dtype == 'object' and df[col].str.contains('ብር|birr|Br|ETB', na=False).any():
            text_column = col
            break

if text_column is None:
    raise ValueError("Could not find a text column in the dataset")

print(f"Using column: {text_column}")

def clean_and_tokenize(text: str) -> list:
    if pd.isna(text) or text == '':
        return []
    text = re.sub(r'\s+', ' ', str(text).strip())
    # Separate numbers and currency but keep them as separate tokens
    text = re.sub(r'(\d+)(ብር|birr|Br|ETB)', r'\1 \2', text)
    # Handle price patterns like **750br**
    text = re.sub(r'\*\*(\d+)(br|ብር)\*\*', r'\1 \2', text)
    return [token for token in text.split() if token.strip()]

def create_sample_labels(df: pd.DataFrame, n: int = 50):
    # Filter messages with potential entities
    df = df[df[text_column].str.contains('ብር|birr|Br|ETB|አዲስ|ቦሌ', na=False)]
    sample_df = df.sample(n=min(n, len(df)), random_state=42)
    labeled_data = []

    for _, row in sample_df.iterrows():
        message = row[text_column]
        if pd.isna(message):
            continue

        tokens = clean_and_tokenize(message)
        labels = ['O'] * len(tokens)

        print(f"\nProcessing message: {message}")
        print(f"Tokens: {tokens}")

        # Process each token
        i = 0
        while i < len(tokens):
            token = tokens[i]
            print(f"Processing token {i}: '{token}'")

            # === PRICE LABELING (HIGHEST PRIORITY) ===
            if token.lower() in ['ዋጋ', 'ዋጋ:', 'ዋጋ፦', 'price', 'price:']:
                print(f"  Found price indicator: {token}")
                labels[i] = 'B-PRICE'
                # Look for following numbers and currency
                j = i + 1
                while j < len(tokens) and j < i + 5:
                    if re.match(r'\d+', tokens[j]):
                        labels[j] = 'I-PRICE'
                        print(f"  Price number: {tokens[j]} -> I-PRICE")
                    elif tokens[j].lower() in ['ብር', 'birr', 'br', 'etb']:
                        labels[j] = 'I-PRICE'
                        print(f"  Price currency: {tokens[j]} -> I-PRICE")
                        break
                    elif tokens[j] in [':', '፦']:
                        labels[j] = 'I-PRICE'
                    else:
                        break
                    j += 1
                i = j
                continue

            elif token == 'በ' and i + 1 < len(tokens) and re.match(r'\d+', tokens[i+1]):
                print(f"  Found 'በ' price pattern")
                labels[i] = 'B-PRICE'
                labels[i+1] = 'I-PRICE'
                if i + 2 < len(tokens) and tokens[i+2].lower() in ['ብር', 'birr', 'br', 'etb']:
                    labels[i+2] = 'I-PRICE'
                    i += 2
                else:
                    i += 1
                continue

            elif re.match(r'\d+', token) and i + 1 < len(tokens) and tokens[i+1].lower() in ['ብር', 'birr', 'br', 'etb']:
                print(f"  Found direct number+currency: {token} {tokens[i+1]}")
                labels[i] = 'B-PRICE'
                labels[i+1] = 'I-PRICE'
                i += 1
                continue

            elif re.match(r'\*\*\d+br\*\*', token.lower()):
                print(f"  Found **numberbr** pattern: {token}")
                labels[i] = 'B-PRICE'

            # === LOCATION LABELING ===
            elif token.lower() == 'አዲስ' and i + 1 < len(tokens) and tokens[i+1].lower() in ['አበባ', 'አበባ,']:
                print(f"  Found 'አዲስ አበባ'")
                labels[i] = 'B-LOC'
                labels[i+1] = 'I-LOC'
                i += 1
                continue

            elif token.replace(',', '').replace('፡', '').replace(':', '').lower() in [
                'ቦሌ', 'መገናኛ', 'ዘፍመሽ', 'ሜክሲኮ', 'ጀሞ', 'ቄራ', 'ፒያሳ', 'መርካቶ'
            ]:
                print(f"  Found location: {token}")
                labels[i] = 'B-LOC'

            # === PRODUCT LABELING (LOWEST PRIORITY) ===
            elif labels[i] == 'O':  # Only if not already labeled
                # Check for exact product matches
                if token.upper() in ['NIKE', 'ADIDAS', 'PUMA', 'CONVERSE']:
                    print(f"  Found brand: {token}")
                    labels[i] = 'B-Product'

                elif token.upper() in ['AIRFORCE', 'AIR', 'FORCE', 'ONE', 'JORDAN']:
                    print(f"  Found product model: {token}")
                    # Check if previous token was already a product
                    if i > 0 and labels[i-1] == 'B-Product':
                        labels[i] = 'I-Product'
                    else:
                        labels[i] = 'B-Product'

                elif token.upper() in ['TSHIRT', 'T-SHIRT', 'JACKET', 'SHIRT', 'DRESS']:
                    print(f"  Found clothing: {token}")
                    labels[i] = 'B-Product'

                elif token in ['ቦርሳ', 'ጫማ', 'ልብስ', 'ሸሚዝ', 'ስልክ']:
                    print(f"  Found Amharic product: {token}")
                    labels[i] = 'B-Product'

                elif token.upper() in ['BRAND', 'ብራንድ', 'QUALITY', 'HIGH', 'CLASSY']:
                    print(f"  Found product descriptor: {token}")
                    if i > 0 and labels[i-1] in ['B-Product', 'I-Product']:
                        labels[i] = 'I-Product'
                    else:
                        labels[i] = 'B-Product'

                elif token.upper() in ['MADE', 'SIZE', 'COLOR']:
                    print(f"  Found product attribute: {token}")
                    # Usually part of product description
                    if i > 0 and labels[i-1] in ['B-Product', 'I-Product']:
                        labels[i] = 'I-Product'
                    # Don't label standalone

                elif token in ['Baby', 'bottle', 'ህፃን', 'ብርጭቆ']:
                    print(f"  Found baby product: {token}")
                    if i > 0 and labels[i-1] == 'B-Product':
                        labels[i] = 'I-Product'
                    else:
                        labels[i] = 'B-Product'

            i += 1

        # Post-processing: Fix label sequences
        for i in range(len(tokens)-1):
            # Convert consecutive B-Product to B-Product + I-Product
            if labels[i] == 'B-Product' and labels[i+1] == 'B-Product':
                labels[i+1] = 'I-Product'
                print(f"  Post-process: {tokens[i+1]} B-Product -> I-Product")

        print(f"Final labels: {labels}")
        labeled_data.append(list(zip(tokens, labels)))

    return labeled_data

def save_sample_conll():
    sample_labels = create_sample_labels(df, n=5)  # Start with just 5 samples for debugging
    with open('amharic_ner_conll.txt', 'w', encoding='utf-8') as f:
        for message_labels in sample_labels:
            for token, label in message_labels:
                f.write(f"{token}\t{label}\n")
            f.write("\n")
    print("CoNLL file created: amharic_ner_conll.txt")

def validate_conll_format(file_path: str):
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            lines = f.readlines()
        message_count = 0
        token_count = 0
        label_stats = {}
        current_message_tokens = 0

        for line in lines:
            line = line.strip()
            if line == '':
                if current_message_tokens > 0:
                    message_count += 1
                    current_message_tokens = 0
            else:
                parts = line.split('\t')
                if len(parts) == 2:
                    token, label = parts
                    token_count += 1
                    current_message_tokens += 1
                    label_stats[label] = label_stats.get(label, 0) + 1
                else:
                    print(f"Warning: Skipping malformed line: '{line}'")

        if current_message_tokens > 0:
            message_count += 1

        print(f"Validation Results for {file_path}:")
        print(f"Messages: {message_count}")
        print(f"Total tokens: {token_count}")
        print(f"Label distribution: {label_stats}")
        return True
    except Exception as e:
        print(f"Error validating file: {e}")
        return False

# Run the functions
save_sample_conll()
validate_conll_format('amharic_ner_conll.txt')
# Out:
# Available columns: ['message_id', 'channel', 'text', 'timestamp', 'views', 'sender', 'image_path']
# First few rows:
#    message_id                channel  \
# 0        4562  @helloomarketethiopia
# 1        4561  @helloomarketethiopia
# 2        4560  @helloomarketethiopia
# 3        4559  @helloomarketethiopia
# 4        4558  @helloomarketethiopia
#
#                                                 text  \
# 0  **ሁለት **ሲገዙ **5%** ቅናሽ ሙሉ በሙሉ የመኝታ ቤትዎን ውበት የሚ...
# 1  የልጆች ወብ ባማረ ዲዛይን የተሰራ ቀሚስ ለማዘዝ 0974312223 ይደውሉ...
# 2  አስደናቄ አትዮጵያዊ ምስልሎች ያላቸው የአረቄ መለኪያ ለማዘዝ 0974312...
# 3  ብዙ ተወዳጀነትን የተረፈ የቃልኪዳን ጉዞ ለሁሉም እድሜ የሚሆን የአማረኛ ...
# 4  ለቤትዎ ደምቀት የሚጨምሩ ሻማዎች በተለያየ መጠን እና ቀለም ለማዘዝ 097...
#
#                    timestamp  views      sender  \
# 0  2025-05-23 13:34:44+00:00   2334  1403573865
# 1  2025-05-16 13:18:16+00:00   3324  1403573865
# 2  2025-05-12 13:45:37+00:00   3626  1403573865
# 3  2025-05-10 09:47:16+00:00   3458  1403573865
# 4  2025-05-09 09:35:20+00:00   3040  1403573865
#
#                                           image_path
# 0  ../data/images/telegram_image_helloomarketethi...
# 1  ../data/images/telegram_image_helloomarketethi...
# 2  ../data/images/telegram_image_helloomarketethi...
# 3  ../data/images/telegram_image_helloomarketethi...
# 4  ../data/images/telegram_image_helloomarketethi...
# Using column: text
#
# Processing message: በደንበኞች ጥያቄ በድጋሚ የገቡ NIKE AIR Size#39#40#41 #42 #43 price 2,800ETB FREE DELIVERY(ያሉበት ቦታ ያለተጨማሪ ክፍያ እናደርሳለን ) ለሱቅና ብዛት ተረካቢዎች ባስተያየት 0977808897 @Naty_boy አድራሻችን-ቄራ ሶፊያ ሞል 2ተኛ ፎቅ 216
# Tokens: ['በደንበኞች', 'ጥያቄ', 'በድጋሚ', 'የገቡ', 'NIKE', 'AIR', 'Size#39#40#41', '#42', '#43', 'price', '2,800', 'ETB', 'FREE', 'DELIVERY(ያሉበት', 'ቦታ', 'ያለተጨማሪ', 'ክፍያ', 'እናደርሳለን', ')', 'ለሱቅና', 'ብዛት', 'ተረካቢዎች', 'ባስተያየት', '0977808897', '@Naty_boy', 'አድራሻችን-ቄራ', 'ሶፊያ', 'ሞል', '2ተኛ', 'ፎቅ', '216']
# Processing token 0: 'በደንበኞች'
# Processing token 1: 'ጥያቄ'
# Processing token 2: 'በድጋሚ'
# Processing token 3: 'የገቡ'
# Processing token 4: 'NIKE'
#   Found brand: NIKE
# Processing token 5: 'AIR'
#   Found product model: AIR
# Processing token 6: 'Size#39#40#41'
# Processing token 7: '#42'
# Processing token 8: '#43'
# Processing token 9: 'price'
#   Found price indicator: price
#   Price number: 2,800 -> I-PRICE
#   Price currency: ETB -> I-PRICE
# Processing token 11: 'ETB'
# Processing token 12: 'FREE'
# Processing token 13: 'DELIVERY(ያሉበት'
# Processing token 14: 'ቦታ'
# Processing token 15: 'ያለተጨማሪ'
# Processing token 16: 'ክፍያ'
# Processing token 17: 'እናደርሳለን'
# Processing token 18: ')'
# Processing token 19: 'ለሱቅና'
# Processing token 20: 'ብዛት'
# Processing token 21: 'ተረካቢዎች'
# Processing token 22: 'ባስተያየት'
# Processing token 23: '0977808897'
# Processing token 24: '@Naty_boy'
# Processing token 25: 'አድራሻችን-ቄራ'
# Processing token 26: 'ሶፊያ'
# Processing token 27: 'ሞል'
# Processing token 28: '2ተኛ'
# Processing token 29: 'ፎቅ'
# Processing token 30: '216'
# Final labels: ['O', 'O', 'O', 'O', 'B-Product', 'I-Product', 'O', 'O', 'O', 'B-PRICE', 'I-PRICE', 'I-PRICE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Processing message: NIKE JORDAN Aerospace 720 Made In VIETNAM Size: #40 #41 #42 #43 #44 #46 Price: 2400 Br Free Delivery INBOX : @Maraki2211 ስልክ : +251 913321831 አድራሻ - አዲስ አበባ, ሜክሲኮ፡ ከ ኬኬር ህንጻ 50ሜ ወረድ ብሎ አይመን ህንፃ ግራውንድ ፍሎር ላይ፡ የሱቅ ቁ.012 Maraki Brand ማራኪ ብራንድ
# Tokens: ['NIKE', 'JORDAN', 'Aerospace', '720', 'Made', 'In', 'VIETNAM', 'Size:', '#40', '#41', '#42', '#43', '#44', '#46', 'Price:', '2400', 'Br', 'Free', 'Delivery', 'INBOX', ':', '@Maraki2211', 'ስልክ', ':', '+251', '913321831', 'አድራሻ', '-', 'አዲስ', 'አበባ,', 'ሜክሲኮ፡', 'ከ', 'ኬኬር', 'ህንጻ', '50ሜ', 'ወረድ', 'ብሎ', 'አይመን', 'ህንፃ', 'ግራውንድ', 'ፍሎር', 'ላይ፡', 'የሱቅ', 'ቁ.012', 'Maraki', 'Brand', 'ማራኪ', 'ብራንድ']
# Processing token 0: 'NIKE'
#   Found brand: NIKE
# Processing token 1: 'JORDAN'
#   Found product model: JORDAN
# Processing token 2: 'Aerospace'
# Processing token 3: '720'
# Processing token 4: 'Made'
#   Found product attribute: Made
# Processing token 5: 'In'
# Processing token 6: 'VIETNAM'
# Processing token 7: 'Size:'
# Processing token 8: '#40'
# Processing token 9: '#41'
# Processing token 10: '#42'
# Processing token 11: '#43'
# Processing token 12: '#44'
# Processing token 13: '#46'
# Processing token 14: 'Price:'
#   Found price indicator: Price:
#   Price number: 2400 -> I-PRICE
#   Price currency: Br -> I-PRICE
# Processing token 16: 'Br'
# Processing token 17: 'Free'
# Processing token 18: 'Delivery'
# Processing token 19: 'INBOX'
# Processing token 20: ':'
# Processing token 21: '@Maraki2211'
# Processing token 22: 'ስልክ'
#   Found Amharic product: ስልክ
# Processing token 23: ':'
# Processing token 24: '+251'
# Processing token 25: '913321831'
# Processing token 26: 'አድራሻ'
# Processing token 27: '-'
# Processing token 28: 'አዲስ'
#   Found 'አዲስ አበባ'
# Processing token 29: 'አበባ,'
# Processing token 30: 'ሜክሲኮ፡'
#   Found location: ሜክሲኮ፡
# Processing token 31: 'ከ'
# Processing token 32: 'ኬኬር'
# Processing token 33: 'ህንጻ'
# Processing token 34: '50ሜ'
# Processing token 35: 'ወረድ'
# Processing token 36: 'ብሎ'
# Processing token 37: 'አይመን'
# Processing token 38: 'ህንፃ'
# Processing token 39: 'ግራውንድ'
# Processing token 40: 'ፍሎር'
# Processing token 41: 'ላይ፡'
# Processing token 42: 'የሱቅ'
# Processing token 43: 'ቁ.012'
# Processing token 44: 'Maraki'
# Processing token 45: 'Brand'
#   Found product descriptor: Brand
# Processing token 46: 'ማራኪ'
# Processing token 47: 'ብራንድ'
#   Found product descriptor: ብራንድ
# Final labels: ['B-Product', 'I-Product', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PRICE', 'I-PRICE', 'I-PRICE', 'O', 'O', 'O', 'O', 'O', 'B-Product', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'I-LOC', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Product', 'O', 'B-Product']
#
# Processing message: ICE Cube Maker Genie Keep Ice-cream cold Keep drinks Ice-cold Easy to use Save a lot of space in your freezer; Keeps your cubes fresh and odor free with air tight lid; ዋጋ፦ 600 ብር Telegram - t.me/qnashcom Website - www.qnash.com ጥራት ዋስትና ቅናሽ አድራሻ መገናኛ ዘፍመሽ ግራንድ ሞል 3 ተኛ ፎቅ ቁጥር 329 ከሊፍት እንደወረዱ በግራ በኩል የፎቁ መጨረሻ ዞር እንዳሉ ስልክ: 0946966440 0905464599 +251118639952
# Tokens: ['ICE', 'Cube', 'Maker', 'Genie', 'Keep', 'Ice-cream', 'cold', 'Keep', 'drinks', 'Ice-cold', 'Easy', 'to', 'use', 'Save', 'a', 'lot', 'of', 'space', 'in', 'your', 'freezer;', 'Keeps', 'your', 'cubes', 'fresh', 'and', 'odor', 'free', 'with', 'air', 'tight', 'lid;', 'ዋጋ፦', '600', 'ብር', 'Telegram', '-', 't.me/qnashcom', 'Website', '-', 'www.qnash.com', 'ጥራት', 'ዋስትና', 'ቅናሽ', 'አድራሻ', 'መገናኛ', 'ዘፍመሽ', 'ግራንድ', 'ሞል', '3', 'ተኛ', 'ፎቅ', 'ቁጥር', '329', 'ከሊፍት', 'እንደወረዱ', 'በግራ', 'በኩል', 'የፎቁ', 'መጨረሻ', 'ዞር', 'እንዳሉ', 'ስልክ:', '0946966440', '0905464599', '+251118639952']
# Processing token 0: 'ICE'
# Processing token 1: 'Cube'
# Processing token 2: 'Maker'
# Processing token 3: 'Genie'
# Processing token 4: 'Keep'
# Processing token 5: 'Ice-cream'
# Processing token 6: 'cold'
# Processing token 7: 'Keep'
# Processing token 8: 'drinks'
# Processing token 9: 'Ice-cold'
# Processing token 10: 'Easy'
# Processing token 11: 'to'
# Processing token 12: 'use'
# Processing token 13: 'Save'
# Processing token 14: 'a'
# Processing token 15: 'lot'
# Processing token 16: 'of'
# Processing token 17: 'space'
# Processing token 18: 'in'
# Processing token 19: 'your'
# Processing token 20: 'freezer;'
# Processing token 21: 'Keeps'
# Processing token 22: 'your'
# Processing token 23: 'cubes'
# Processing token 24: 'fresh'
# Processing token 25: 'and'
# Processing token 26: 'odor'
# Processing token 27: 'free'
# Processing token 28: 'with'
# Processing token 29: 'air'
#   Found product model: air
# Processing token 30: 'tight'
# Processing token 31: 'lid;'
# Processing token 32: 'ዋጋ፦'
#   Found price indicator: ዋጋ፦
#   Price number: 600 -> I-PRICE
#   Price currency: ብር -> I-PRICE
# Processing token 34: 'ብር'
# Processing token 35: 'Telegram'
# Processing token 36: '-'
# Processing token 37: 't.me/qnashcom'
# Processing token 38: 'Website'
# Processing token 39: '-'
# Processing token 40: 'www.qnash.com'
# Processing token 41: 'ጥራት'
# Processing token 42: 'ዋስትና'
# Processing token 43: 'ቅናሽ'
# Processing token 44: 'አድራሻ'
# Processing token 45: 'መገናኛ'
#   Found location: መገናኛ
# Processing token 46: 'ዘፍመሽ'
#   Found location: ዘፍመሽ
# Processing token 47: 'ግራንድ'
# Processing token 48: 'ሞል'
# Processing token 49: '3'
# Processing token 50: 'ተኛ'
# Processing token 51: 'ፎቅ'
# Processing token 52: 'ቁጥር'
# Processing token 53: '329'
# Processing token 54: 'ከሊፍት'
# Processing token 55: 'እንደወረዱ'
# Processing token 56: 'በግራ'
# Processing token 57: 'በኩል'
# Processing token 58: 'የፎቁ'
# Processing token 59: 'መጨረሻ'
# Processing token 60: 'ዞር'
# Processing token 61: 'እንዳሉ'
# Processing token 62: 'ስልክ:'
# Processing token 63: '0946966440'
# Processing token 64: '0905464599'
# Processing token 65: '+251118639952'
# Final labels: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Product', 'O', 'O', 'B-PRICE', 'I-PRICE', 'I-PRICE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Processing message: Telegram - t.me/qnashcom የልብስ ማስጫ ለክረምት ለበጋ የሚሆን የልብስ ማስጫ ይዘንሎት መተናል ልብስ በትንሽ ቦታ ማድረቅ የሚያስችል አስደናቂ ማስጫ Retractable Cloth line Rope #በበረንዳ #በባኞ #በእቃቤት ተገጥሞ አገልግሎት የሚሰጥ #ብርድልብሶች #ጋቢ #ሱሪ #ሸሚዞች #ሹራቦች የሚያሰጣ 4.2ሜትር ርዝመት ያለው ገመዱ በራሱ የሚጠቀልል የማይዝግ ጠንካራ የብረት ሽቦ ገመድ ዋጋ፦ 1400 ብር 1200 ብር አድራሻ መገናኛ ዘፍመሽ ግራንድ ሞል 3 ተኛ ፎቅ ቁጥር 329 ስልክ: 0946966440 0905464599 +251118639952 ያሉበት በነፃ እናመጣለን
# Tokens: ['Telegram', '-', 't.me/qnashcom', 'የልብስ', 'ማስጫ', 'ለክረምት', 'ለበጋ', 'የሚሆን', 'የልብስ', 'ማስጫ', 'ይዘንሎት', 'መተናል', 'ልብስ', 'በትንሽ', 'ቦታ', 'ማድረቅ', 'የሚያስችል', 'አስደናቂ', 'ማስጫ', 'Retractable', 'Cloth', 'line', 'Rope', '#በበረንዳ', '#በባኞ', '#በእቃቤት', 'ተገጥሞ', 'አገልግሎት', 'የሚሰጥ', '#ብርድልብሶች', '#ጋቢ', '#ሱሪ', '#ሸሚዞች', '#ሹራቦች', 'የሚያሰጣ', '4.2ሜትር', 'ርዝመት', 'ያለው', 'ገመዱ', 'በራሱ', 'የሚጠቀልል', 'የማይዝግ', 'ጠንካራ', 'የብረት', 'ሽቦ', 'ገመድ', 'ዋጋ፦', '1400', 'ብር', '1200', 'ብር', 'አድራሻ', 'መገናኛ', 'ዘፍመሽ', 'ግራንድ', 'ሞል', '3', 'ተኛ', 'ፎቅ', 'ቁጥር', '329', 'ስልክ:', '0946966440', '0905464599', '+251118639952', 'ያሉበት', 'በነፃ', 'እናመጣለን']
# Processing token 0: 'Telegram'
# Processing token 1: '-'
# Processing token 2: 't.me/qnashcom'
# Processing token 3: 'የልብስ'
# Processing token 4: 'ማስጫ'
# Processing token 5: 'ለክረምት'
# Processing token 6: 'ለበጋ'
# Processing token 7: 'የሚሆን'
# Processing token 8: 'የልብስ'
# Processing token 9: 'ማስጫ'
# Processing token 10: 'ይዘንሎት'
# Processing token 11: 'መተናል'
# Processing token 12: 'ልብስ'
#   Found Amharic product: ልብስ
# Processing token 13: 'በትንሽ'
# Processing token 14: 'ቦታ'
# Processing token 15: 'ማድረቅ'
# Processing token 16: 'የሚያስችል'
# Processing token 17: 'አስደናቂ'
# Processing token 18: 'ማስጫ'
# Processing token 19: 'Retractable'
# Processing token 20: 'Cloth'
# Processing token 21: 'line'
# Processing token 22: 'Rope'
# Processing token 23: '#በበረንዳ'
# Processing token 24: '#በባኞ'
# Processing token 25: '#በእቃቤት'
# Processing token 26: 'ተገጥሞ'
# Processing token 27: 'አገልግሎት'
# Processing token 28: 'የሚሰጥ'
# Processing token 29: '#ብርድልብሶች'
# Processing token 30: '#ጋቢ'
# Processing token 31: '#ሱሪ'
# Processing token 32: '#ሸሚዞች'
# Processing token 33: '#ሹራቦች'
# Processing token 34: 'የሚያሰጣ'
# Processing token 35: '4.2ሜትር'
# Processing token 36: 'ርዝመት'
# Processing token 37: 'ያለው'
# Processing token 38: 'ገመዱ'
# Processing token 39: 'በራሱ'
# Processing token 40: 'የሚጠቀልል'
# Processing token 41: 'የማይዝግ'
# Processing token 42: 'ጠንካራ'
# Processing token 43: 'የብረት'
# Processing token 44: 'ሽቦ'
# Processing token 45: 'ገመድ'
# Processing token 46: 'ዋጋ፦'
#   Found price indicator: ዋጋ፦
#   Price number: 1400 -> I-PRICE
#   Price currency: ብር -> I-PRICE
# Processing token 48: 'ብር'
# Processing token 49: '1200'
#   Found direct number+currency: 1200 ብር
# Processing token 50: 'ብር'
# Processing token 51: 'አድራሻ'
# Processing token 52: 'መገናኛ'
#   Found location: መገናኛ
# Processing token 53: 'ዘፍመሽ'
#   Found location: ዘፍመሽ
# Processing token 54: 'ግራንድ'
# Processing token 55: 'ሞል'
# Processing token 56: '3'
# Processing token 57: 'ተኛ'
# Processing token 58: 'ፎቅ'
# Processing token 59: 'ቁጥር'
# Processing token 60: '329'
# Processing token 61: 'ስልክ:'
# Processing token 62: '0946966440'
# Processing token 63: '0905464599'
# Processing token 64: '+251118639952'
# Processing token 65: 'ያሉበት'
# Processing token 66: 'በነፃ'
# Processing token 67: 'እናመጣለን'
# Final labels: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Product', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PRICE', 'I-PRICE', 'I-PRICE', 'B-PRICE', 'I-PRICE', 'O', 'B-LOC', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Processing message: New Arrival Reebok Classic legacy Available On Hand Size 40'41' 42' 43' Price #2,899birr Contact @naty_boy Phone +251977808897 Arada Brand አራዳ ብራንድ https://t.me/+U06glriPOuJ1ZU_l We Are Happy To Announce Only Available @ Our Store
# Tokens: ['New', 'Arrival', 'Reebok', 'Classic', 'legacy', 'Available', 'On', 'Hand', 'Size', "40'41'", "42'", "43'", 'Price', '#2,899', 'birr', 'Contact', '@naty_boy', 'Phone', '+251977808897', 'Arada', 'Brand', 'አራዳ', 'ብራንድ', 'https://t.me/+U06glriPOuJ1ZU_l', 'We', 'Are', 'Happy', 'To', 'Announce', 'Only', 'Available', '@', 'Our', 'Store']
# Processing token 0: 'New'
# Processing token 1: 'Arrival'
# Processing token 2: 'Reebok'
# Processing token 3: 'Classic'
# Processing token 4: 'legacy'
# Processing token 5: 'Available'
# Processing token 6: 'On'
# Processing token 7: 'Hand'
# Processing token 8: 'Size'
#   Found product attribute: Size
# Processing token 9: '40'41''
# Processing token 10: '42''
# Processing token 11: '43''
# Processing token 12: 'Price'
#   Found price indicator: Price
# Processing token 13: '#2,899'
# Processing token 14: 'birr'
# Processing token 15: 'Contact'
# Processing token 16: '@naty_boy'
# Processing token 17: 'Phone'
# Processing token 18: '+251977808897'
# Processing token 19: 'Arada'
# Processing token 20: 'Brand'
#   Found product descriptor: Brand
# Processing token 21: 'አራዳ'
# Processing token 22: 'ብራንድ'
#   Found product descriptor: ብራንድ
# Processing token 23: 'https://t.me/+U06glriPOuJ1ZU_l'
# Processing token 24: 'We'
# Processing token 25: 'Are'
# Processing token 26: 'Happy'
# Processing token 27: 'To'
# Processing token 28: 'Announce'
# Processing token 29: 'Only'
# Processing token 30: 'Available'
# Processing token 31: '@'
# Processing token 32: 'Our'
# Processing token 33: 'Store'
# Final labels: ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PRICE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Product', 'O', 'B-Product', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# CoNLL file created: amharic_ner_conll.txt
# Validation Results for amharic_ner_conll.txt:
# Messages: 5
# Total tokens: 247
# Label distribution: {'O': 214, 'B-Product': 9, 'I-Product': 2, 'B-PRICE': 6, 'I-PRICE': 9, 'B-LOC': 6, 'I-LOC': 1}
# True

# %%
# Final Steps and Instructions

def main_labeling_workflow():
    """
    Main workflow for labeling process
    """
    print("AMHARIC NER LABELING WORKFLOW")
    print("=" * 40)
    print("1. Load your telegram_data.csv file")
    print("2. Run the interactive labeling session")
    print("3. Label 30-50 messages minimum")
    print("4. Save in CoNLL format")
    print("5. Validate the output")
    print("\nTo start labeling:")
    print("1. Uncomment the interactive_labeling_session call above")
    print("2. Run the cells step by step")
    print("3. Follow the prompts to label each token")

    print("\nRemember:")
    print("- B- prefix for beginning of entity")
    print("- I- prefix for inside/continuation of entity")
    print("- O for outside any entity")
    print("- Products: items being sold")
    print("- Locations: places mentioned")
    print("- Prices: monetary amounts")

main_labeling_workflow()
# Out:
# AMHARIC NER LABELING WORKFLOW
# ========================================
# 1. Load your telegram_data.csv file
# 2. Run the interactive labeling session
# 3. Label 30-50 messages minimum
# 4. Save in CoNLL format
# 5. Validate the output
#
# To start labeling:
# 1. Uncomment the interactive_labeling_session call above
# 2. Run the cells step by step
# 3. Follow the prompts to label each token
#
# Remember:
# - B- prefix for beginning of entity
# - I- prefix for inside/continuation of entity
# - O for outside any entity
# - Products: items being sold
# - Locations: places mentioned
# - Prices: monetary amounts
